# %% [markdown]
# <a href="https://colab.research.google.com/github/ulyazzh/Latihan_STKI/blob/main/Tugas4_STKI/berita2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from nltk.tokenize import word_tokenize
import string
import re
import nltk
nltk.download('punkt_tab')

punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''

df = pd.read_csv("datasetberita.csv", header=None, sep='\r\n', engine='python', names=['berita'])

dataset = pd.read_csv('datasetberita.csv')
dataset.head(20)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#       ID  label    tanggal                                              judul  \
# 0     71      1  17-Aug-20  Pemakaian Masker Menyebabkan Penyakit Legionna...
# 1    461      1  17-Jul-20  Instruksi Gubernur Jateng tentang penilangan  ...
# 2    495      1  13-Jul-20  Foto Jim Rohn: Jokowi adalah presiden terbaik ...
# 3    550      1   8-Jul-20  ini bukan politik, tapi kenyataan Pak Jokowi b...
# 4    681      1  24-Jun-20       Foto Kadrun kalo lihat foto ini panas dingin
# 5    736      1  17-Jun-20  event promo smartphone JNE 2020 spesial di bul...
# 6   1161      1   5-May-20  MEREKA SUDAH MEMPERSIAPKAN DIRI DENGAN BAIK UN...
# 7   1597      1  24-Mar-20  Foto Presiden Italia menangis karena tak cukup...
# 8   2098      1   9-Jan-20  Kapolres Timor Tengah Utara , Nusa Tenggara Ti...
# ...

# %%
#lowercase
df['lowercase'] = df['berita'].apply(lambda x: (x.lower()))

print (df['lowercase'])
# Out:
# 0          id,label,tanggal,judul,narasi,nama file gambar
# 1       71,1,17-aug-20,pemakaian masker menyebabkan pe...
# 2       461,1,17-jul-20,instruksi gubernur jateng tent...
# 3       495,1,13-jul-20,foto jim rohn: jokowi adalah p...
# 4       550,1,8-jul-20,"ini bukan politik, tapi kenyat...
#                               ...
# 6749    999287,1,17-jan-16,: kpk dilarang membawa brim...
# 6750    999472,1,20-aug-20,foto pejabat keuangan dibaw...
# 6751    999501,1,17-aug-20,gambar denny siregar musuh ...
# 6752    999848,1,21-jul-20,kaesang: bapak saya dengan ...
# 6753    999860,1,20-jul-20,laser dari termometer gun a...
# Name: lowercase, Length: 6754, dtype: object

# %%
#generate tokens
df['tokens'] = df['lowercase'].apply(lambda x: word_tokenize(x))

print(df['tokens'])
# Out:
# 0       [id, ,, label, ,, tanggal, ,, judul, ,, narasi...
# 1       [71,1,17-aug-20, ,, pemakaian, masker, menyeba...
# 2       [461,1,17-jul-20, ,, instruksi, gubernur, jate...
# 3       [495,1,13-jul-20, ,, foto, jim, rohn, :, jokow...
# 4       [550,1,8-jul-20, ,, '', ini, bukan, politik, ,...
#                               ...
# 6749    [999287,1,17-jan-16, ,, :, kpk, dilarang, memb...
# 6750    [999472,1,20-aug-20, ,, foto, pejabat, keuanga...
# 6751    [999501,1,17-aug-20, ,, gambar, denny, siregar...
# 6752    [999848,1,21-jul-20, ,, kaesang, :, bapak, say...
# 6753    [999860,1,20-jul-20, ,, laser, dari, termomete...
# Name: tokens, Length: 6754, dtype: object

# %%
df['lowercase'] = df['lowercase'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))


print(df['lowercase'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6826baca9e19> in <cell line: 1>()
# ----> 1 df['lowercase'] = df['lowercase'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
#       2
#       3
#       4 print(df['lowercase'])
#
# NameError: name 'df' is not defined

# %%
df['lowercase'] = df['lowercase'].apply(lambda x: (re.sub(r'[\w\s]', '', x)))
print (df['lowercase'])
